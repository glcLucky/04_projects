# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import numpy as np
import pandas as pd

import devkit.api as dk
import finkit.api as fk
import DataAPI
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
trading_days_ts = fk.get_monthly_last_trading_days(start="2016-01-01", end="2018-05-31")
trading_days_fr = fk.get_report_days(start="2016-01-01", end="2018-12-31")

# %%
hs300_sec_ids = pd.read_csv(r"E:\07_data\02_factor\temp_data\hs300.csv")['wind_code'].tolist()

# %%
DataAPI.read.get_secs_indicator_on_multidays(indicator='VAL_PE_DEDUCTED_TTM', sec_ids=hs300_sec_ids, trading_days=trading_days_ts)
# Out:
# {'2016-01-29':         sec_id  VAL_PE_DEDUCTED_TTM
#  0    000001.SZ             6.538419
#  1    000002.SZ            16.815055
#  2    000060.SZ           196.546238
#  3    000063.SZ            24.922854
#  4    000069.SZ            13.677075
#  5    000100.SZ            21.360783
#  6    000157.SZ           -23.992135
#  7    000166.SZ                  NaN
#  8    000333.SZ            11.394421
#  9    000338.SZ            21.269934
#  10   000402.SZ            15.891693
#  11   000413.SZ            39.300472
#  12   000415.SZ            40.245523
#  13   000423.SZ            19.869857
#  14   000425.SZ           -23.162259
#  15   000503.SZ          -187.933506
#  16   000538.SZ            25.401335
#  17   000540.SZ            16.367042
#  18   000559.SZ            45.197085
#  19   000568.SZ            31.493396
#  20   000623.SZ             8.681418
#  21   000625.SZ             8.230498
#  22   000627.SZ           -70.333787
#  23   000630.SZ           301.535574
# ...
