# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd

import devkit.api as dk
import finkit.api as fk
import DataAPI
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ---
#
# # 数据库架构

# %%
db_names = [
    "index_contents",  # 股票列表
    "industry",  # 行业分类
    "indicator",  # 基础指标
    "factor",  # 因子
    "factor_return",  # 因子收益
]

# db_name = "INDICATOR"
for db_name in db_names:
    DataAPI.show_db_info(db_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-f81089a55725> in <module>()
#       9 # db_name = "INDICATOR"
#      10 for db_name in db_names:
# ---> 11     DataAPI.show_db_info(db_name)
#
# AttributeError: module 'DataAPI' has no attribute 'show_db_info'

# %% [markdown]
# ---
#
# # 待更新日期

# %%
start = "2018-01-01"
end = "2018-03-01"
trading_days = fk.get_trading_days(start=start, end=end)
#trading_days = list(set(fk.get_trading_days(start=start, end=end)).union(set(fk.get_report_days(start=start, end=end))))
trading_days = sorted(trading_days)

# %% [markdown]
# ---
#
# # indicator

# %%
indicators = ["PCF_OCF_TTM"]  # 为空表示更新所有存在的indicator
DataAPI.write.update_indicators(indicators, trading_days, override=False, log=False)
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# [WARN] 2018-04-22 09:11:50 Empty result when reading A at 2018-03-05
# [ERROR] 2018-04-22 09:11:50 Error occurred when loading PCF_OCF_TTM on 2018-03-05
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\04_project\DataAPI\write\indicator.py in update_single_indicator(indicator, trading_days, override, log)
#      78                 try:
# ---> 79                     df = load_single_indicator_on_single_day_from_wind(indicator=indicator, date=date)
#      80                 except Exception:
#
# E:\04_project\DataAPI\load\indicator.py in load_single_indicator_on_single_day_from_wind(indicator, date, log)
#      64     )
# ---> 65     WindAPI.test_error(response)
#      66     df = {field: response.Data[i] for i, field in enumerate(response.Fields)}
#
# E:\04_project\WindAPI\utils.py in test_error(response)
#      21     if response.ErrorCode:
# ---> 22         raise ValueError(response.Data[0][0])
#      23
#
# ValueError: CWSSService: invalid windcodes.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-1f6d3e44579c> in <module>()
#       1 indicators = ["PCF_OCF_TTM"]  # 为空表示更新所有存在的indicator
# ----> 2 DataAPI.write.update_indicators(indicators, trading_days, override=False, log=False)
#
# E:\04_project\DataAPI\write\indicator.py in update_indicators(indicators, trading_days, override, log)
#     137                 Logger.warn("No valid days to update!")
#     138             else:
# --> 139                 update_single_indicator(indicator=ind, trading_days=update_days, override=override, log=log)
#     140         else:
#     141             Logger.error("Unrecognized indicator: {}".format(ind))
#
# E:\04_project\DataAPI\write\indicator.py in update_single_indicator(indicator, trading_days, override, log)
#      80                 except Exception:
#      81                     Logger.error("Error occurred when loading {} on {}".format(indicator, date))
# ---> 82                     raise ValueError
#      83
#      84                 if df is not None:  # 从Wind下载数据成功时
#
# ValueError:

# %% [markdown]
# ---
#
# # factor

# %%
factors1 = ['BETA', "CURRENT", "EBITOFREVENUE", "MOM", "ROE", "VOL",]  # 直接取
factors2 = ["SIZE","LIQ", "DEBTTOASSETS"] # ?取对数
factors3 = ['VALUE', 'GROWTH'] # 需转换
factors4 = ["LEVERAGE","PROFIT"] # 基于其他做好的factor
DataAPI.write.update_factors(factors=factors1,trading_days=trading_days , override=False, log=False)
DataAPI.write.update_factors(factors=factors2,trading_days=trading_days , override=False, log=False)
DataAPI.write.update_factors(factors=factors3,trading_days=trading_days , override=False, log=False)
DataAPI.write.update_factors(factors=factors4,trading_days=trading_days , override=False, log=False)

# %%
DataAPI.write.update_factors(factors=['GROWTH'],trading_days=trading_days, override=True, log=False)
# Out:
# [INFO] 2018-03-14 13:12:13 Updating factor GROWTH
# [WARN] 2018-03-14 13:17:57 由于 2018-01-02 值缺失太多直接复制于 2017-12-29
# [WARN] 2018-03-14 13:17:57 由于 2018-01-03 值缺失太多直接复制于 2018-01-02
# [WARN] 2018-03-14 13:17:58 由于 2018-01-04 值缺失太多直接复制于 2018-01-03
# [WARN] 2018-03-14 13:17:58 由于 2018-01-05 值缺失太多直接复制于 2018-01-04
# [WARN] 2018-03-14 13:17:59 由于 2018-01-08 值缺失太多直接复制于 2018-01-05
# [WARN] 2018-03-14 13:17:59 由于 2018-01-09 值缺失太多直接复制于 2018-01-08
# [WARN] 2018-03-14 13:17:59 由于 2018-01-10 值缺失太多直接复制于 2018-01-09
# [WARN] 2018-03-14 13:18:00 由于 2018-01-11 值缺失太多直接复制于 2018-01-10
# [WARN] 2018-03-14 13:18:00 由于 2018-01-12 值缺失太多直接复制于 2018-01-11
# [WARN] 2018-03-14 13:18:00 由于 2018-01-15 值缺失太多直接复制于 2018-01-12
# [WARN] 2018-03-14 13:18:01 由于 2018-01-16 值缺失太多直接复制于 2018-01-15
# [WARN] 2018-03-14 13:18:01 由于 2018-01-17 值缺失太多直接复制于 2018-01-16
# [WARN] 2018-03-14 13:18:01 由于 2018-01-18 值缺失太多直接复制于 2018-01-17
# [WARN] 2018-03-14 13:18:02 由于 2018-01-19 值缺失太多直接复制于 2018-01-18
# [WARN] 2018-03-14 13:18:02 由于 2018-01-22 值缺失太多直接复制于 2018-01-19
# [WARN] 2018-03-14 13:18:03 由于 2018-01-23 值缺失太多直接复制于 2018-01-22
# [WARN] 2018-03-14 13:18:03 由于 2018-01-24 值缺失太多直接复制于 2018-01-23
# [WARN] 2018-03-14 13:18:03 由于 2018-01-25 值缺失太多直接复制于 2018-01-24
# [WARN] 2018-03-14 13:18:04 由于 2018-01-26 值缺失太多直接复制于 2018-01-25
# [WARN] 2018-03-14 13:18:04 由于 2018-01-29 值缺失太多直接复制于 2018-01-26
# [WARN] 2018-03-14 13:18:04 由于 2018-01-30 值缺失太多直接复制于 2018-01-29
# [WARN] 2018-03-14 13:18:05 由于 2018-01-31 值缺失太多直接复制于 2018-01-30
# [WARN] 2018-03-14 13:18:05 由于 2018-02-01 值缺失太多直接复制于 2018-01-31
# [WARN] 2018-03-14 13:18:05 由于 2018-02-02 值缺失太多直接复制于 2018-02-01
# [WARN] 2018-03-14 13:18:06 由于 2018-02-05 值缺失太多直接复制于 2018-02-02
# [WARN] 2018-03-14 13:18:06 由于 2018-02-06 值缺失太多直接复制于 2018-02-05
# [WARN] 2018-03-14 13:18:07 由于 2018-02-07 值缺失太多直接复制于 2018-02-06
# [WARN] 2018-03-14 13:18:07 由于 2018-02-08 值缺失太多直接复制于 2018-02-07
# [WARN] 2018-03-14 13:18:07 由于 2018-02-09 值缺失太多直接复制于 2018-02-08
# [WARN] 2018-03-14 13:18:08 由于 2018-02-12 值缺失太多直接复制于 2018-02-09
# [WARN] 2018-03-14 13:18:08 由于 2018-02-13 值缺失太多直接复制于 2018-02-12
# [WARN] 2018-03-14 13:18:09 由于 2018-02-14 值缺失太多直接复制于 2018-02-13
# [WARN] 2018-03-14 13:18:09 由于 2018-02-22 值缺失太多直接复制于 2018-02-14
# [WARN] 2018-03-14 13:18:09 由于 2018-02-23 值缺失太多直接复制于 2018-02-22
# [WARN] 2018-03-14 13:18:10 由于 2018-02-26 值缺失太多直接复制于 2018-02-23
# [WARN] 2018-03-14 13:18:10 由于 2018-02-27 值缺失太多直接复制于 2018-02-26
# [WARN] 2018-03-14 13:18:11 由于 2018-02-28 值缺失太多直接复制于 2018-02-27
# [WARN] 2018-03-14 13:18:11 由于 2018-03-01 值缺失太多直接复制于 2018-02-28
# [WARN] 2018-03-14 13:18:11 由于 2018-03-02 值缺失太多直接复制于 2018-03-01
# [INFO] 2018-03-14 13:18:12 schema updated: GROWTH

# %% [markdown]
# ---
#
# # factor_return

# %%
# factors = ["SIZE", 'VALUE', 'BETA', 'VOL', 'ROE', 'MOM', 'LIQ'] # 为空表示更新所有存在的factors
factors = []
DataAPI.write.update_factors_return(['GROWTH'], trading_days)
# Out:
# [INFO] 2018-03-14 16:13:50 Updating factor_return GROWTH...
# [INFO] 2018-03-14 16:14:57 存量更新：更新当前已经有的记录
# [INFO] 2018-03-14 16:14:57 schema updated: GROWTH
# [INFO] 2018-03-14 16:14:57 传入日期数：1015  已经存在个数：1  实际写入次数：1014
# [INFO] 2018-03-14 16:14:57 factor_return GROWTH is updated.
# [INFO] 2018-03-14 16:14:57 ------------------------------------------
