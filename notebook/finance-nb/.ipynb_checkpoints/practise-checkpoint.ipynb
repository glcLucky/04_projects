# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import self_plan.finance.api as fa
import seaborn, datetime
seaborn.set_style("darkgrid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5ff288391e94> in <module>()
#       1 import pandas as pd
# ----> 2 import self_plan.finance.api as fa
#       3 import seaborn, datetime
#       4 seaborn.set_style("darkgrid")
#
# E:\04_project\self_plan\__init__.py in <module>()
#       3
#       4 from . config import preference
# ----> 5 from . finance import *
#
# E:\04_project\self_plan\finance\__init__.py in <module>()
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from . import api
#
# E:\04_project\self_plan\finance\api.py in <module>()
#      11 """
#      12
# ---> 13 from . data import *
#
# E:\04_project\self_plan\finance\data.py in <module>()
#       6 import numpy as np
#       7
# ----> 8 from config import db_path
#       9
#      10 fin_plan_path = os.path.join(db_path, "financial_plan_2018.xlsx")
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# # 1. 获得数据集

# %%
df = fa.load_excel_data(fa.fin_plan_path)

# %% [markdown]
# # 2. 获取净资产总额

# %%
fa.get_current_net_asset(df)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-9f88d5e52e87> in <module>()
# ----> 1 fa.get_current_net_asset(df)
#
# E:\04_project\code\python\module\self_plan\finance\data.py in get_current_net_asset(df_all)
#      38         date_list[-1]].merge(data_raw[date_list[-2]], how="inner", left_index=True, right_index=True)
#      39     output['change'] = output['current_value'] - output["previous_value"]
# ---> 40     output.to_csv(os.path.join(db_path, "net_asset_amount", "{}.csv".format(date_list[-1])))
#      41     return output
#      42
#
# E:\06_software\Anoconda\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# E:\06_software\Anoconda\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# E:\06_software\Anoconda\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# OSError: [Errno 22] Invalid argument: 'E:\\01_learn\\05_method\\net_asset_amount\\2018-02-09 00:00:00.csv'

# %% [markdown]
# # 3. 获得净资产变动趋势

# %%
fa.get_net_asset_trend(df)
# Out:
#                  净资产
# 2018-01-08  540624.0
# 2018-01-25  551849.0
# 2018-02-03  551367.0
# 2018-02-09  561548.0

# %% [markdown]
# # 4. 获得当前资产结构

# %%
fa.get_current_asset_structure(df)
# Out:
#           current_value       pct  planning_prop  planning_value  comments
# subclass
# P2P             91672.0  0.155633          0.050        29451.40 -62220.60
# 偏股型基金           24539.0  0.041660          0.030        17670.84  -6868.16
# 定期             428462.0  0.727405          0.800       471222.40  42760.40
# 指数型基金           12350.0  0.020967          0.030        17670.84   5320.84
# 现金              21505.0  0.036509          0.010         5890.28 -15614.72
# 股票              10500.0  0.017826          0.025        14725.70   4225.70
# total          589028.0  1.000000            NaN             NaN       NaN

# %% [markdown]
# # 5. 获得固收类资产流动性结构信息

# %%
fa.get_fixed_equity_liq_structure(df_all=df,timedelta=15)
# Out:
# 即将要到期的品种:
# Empty DataFrame
# Columns: [channel, category, item, total_amount, maturity, remain_days]
# Index: []
#           total_amount       pct  planning_prop  total_fix_mv  planning_value  \
# subclass
# 中期定期            198111  0.465793           0.80      428462.0        342769.6
# 短期定期             73031  0.171708           0.10      428462.0         42846.2
# 超长期定期            38173  0.089751           0.05      428462.0         21423.1
# 长期定期            116005  0.272748           0.05      428462.0         21423.1
#
#           comments
# subclass
# 中期定期      144658.6
# 短期定期      -30184.8
# 超长期定期     -16749.9
# 长期定期      -94581.9

# %% [markdown]
# # 6. 获得固收类资产收益率

# %%
fa.get_ret_rate_for_fixed_asset(df)
# Out:
#                  channel subclass     ytm   ytm_avg remain_days  weight
# item
# U计划7058期             人人贷     中期定期  0.0920  0.061794    132 days   2.46%
# U计划0613期             人人贷     中期定期  0.0880  0.061794    126 days   0.98%
# U计划6013期             人人贷     中期定期  0.0880  0.061794     96 days   7.94%
# U计划8417期             人人贷     长期定期  0.0880  0.061794    199 days   5.08%
# U计划0521期             人人贷     中期定期  0.0810  0.061794    103 days   4.93%
# 光大永明定活宝20180717    微信理财通     中期定期  0.0600  0.061794    159 days   8.94%
# 光大永明定活宝20180726    微信理财通     中期定期  0.0600  0.061794    168 days   4.83%
# 京弘年年盈               京东金融     长期定期  0.0580  0.061794    230 days   3.57%
# 京弘年年盈               京东金融     长期定期  0.0580  0.061794    181 days   1.20%
# 厦金中心厦盈通第八期         微信理财通     中期定期  0.0568  0.061794    119 days   7.29%
# 厦金中心厦盈通第二期         微信理财通     中期定期  0.0568  0.061794    108 days   2.43%
# 平安享盈368            微信理财通     长期定期  0.0560  0.061794    339 days   7.76%
# 光大永明定活宝20190108    微信理财通     长期定期  0.0550  0.061794    333 days   3.69%
# 光大永明定活宝20190208    微信理财通    超长期定期  0.0550  0.061794    364 days   4.70%
# 理享HK731              陆金所    超长期定期  0.0550  0.061794    700 days   1.76%
# 理享HK730              陆金所    超长期定期  0.0550  0.061794    699 days   2.52%
# 泰康养老瑞泰             微信理财通     长期定期  0.0540  0.061794    313 days   2.36%
# 京弘年年盈               京东金融     中期定期  0.0540  0.061794    131 days   4.82%
# 光大永明定活宝20180514    微信理财通     中期定期  0.0510  0.061794     95 days   1.94%
# 天金所支信通第33期         微信理财通     短期定期  0.0510  0.061794     61 days   1.22%
# 天金所支信通第35期         微信理财通     短期定期  0.0510  0.061794     70 days   3.66%
# 太平养老乐享太平20180817   微信理财通     长期定期  0.0504  0.061794    189 days   2.36%
# 太平养老乐享太平20180320   微信理财通     短期定期  0.0502  0.061794     39 days  12.29%
# 理享CS365              陆金所     长期定期  0.0500  0.061794    334 days   1.25%

# %% [markdown]
# # 7. 获得权益类资产收益率

# %%
fa.get_ret_rate_for_equity_asset(df)
# Out:
#                  status hold_days  buy_cost  current_value  return return_rate
# item
# 华域汽车                持仓中   23 days   10602.0        10500.0  -102.0      -0.96%
# 广发沪深300ETF002987    持仓中   49 days   13900.0        12350.0 -1550.0     -11.15%
# 银华估值005250          持仓中   61 days   25970.0        24539.0 -1431.0      -5.51%
# 上海医药               落袋为安   60 days    9726.4            NaN   445.6       4.58%
# 康缘医药               落袋为安   60 days    1526.0            NaN  -120.0      -7.86%
# 持仓总计                NaN       NaT   50472.0            NaN -3083.0      -6.11%
# 已实现总计               NaN       NaT   11252.4            NaN   325.6       2.89%
# 总计                  NaN       NaT  123448.8            NaN -5514.8      -4.47%

# %% [markdown]
# # 8. 获得期间金融资产收益率及当期消费

# %%
fa.get_period_return_and_expense(df_all=df, start_date='2018-02-03', end_date='2018-02-09')
# Out:
#             start_date  income_from_parents  begin_net_asset  end_net_asset  \
# 2018-02-09  2018-02-03              15797.0         551367.0       561548.0
#
#             return_finance  expense
# 2018-02-09         -2532.0   3084.0

# %% [markdown]
# # 9. 获得当前净资产与当前来自父母总收入的差额

# %%
# 越大约好
fa.get_diff(df)
# Out:
# 当前净资产-来自父母的总收入=  -52696.0

# %%
def create_db(path, index_col, table_name):
    """创建db并创建索引 for indicator and factor"""
    conn = sqlite3.connect(os.path.join(path, "{}.db".format(year)))
    cursor = conn.cursor()
    exec_text1 = '''
        CREATE TABLE {} 
        (date CHAR(10) NOT NULL,
         sec_id TEXT NOT NULL,
         {} REAL 
        )
        '''.format(table_name, table_name)
    print(exec_text1)
    try:
        cursor.execute(exec_text1)
    except Exception:
        traceback.print_exc()
    finally:
        conn.close()

# %%
import sqlite3,os

# %%
conn = sqlite3.connect(os.path.join(fa.db_path, "finance.db"))

# %%
cursor = conn.cursor()

# %%
cursor.execute("CREATE ")
