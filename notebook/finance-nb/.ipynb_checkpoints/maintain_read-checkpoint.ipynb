# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import finance.api as fa
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 读取最近12期净资产总额

# %%
# 给定起始和结束日期 默认为读取所有日期 
fa.get_net_asset_amount()
# Out:
#             current_value
# date
# 2018-01-01      540624.00
# 2018-02-01      551367.00
# 2018-03-01      587982.00
# 2018-04-01      629240.94
# 2018-05-01      726121.26
# 2018-06-01      910124.50
# 2018-09-01      392518.51
# 2018-12-01      382061.00
# 2019-01-01      367113.55

# %% [markdown]
# # 读取理财资产和非理财资产构成情况

# %%
# 默认读取最新日期
fa.get_account_type()  #  判断理财与非理财资产构成是否合理
# Out:
# [INFO] 2019-01-01 14:25:21
# *****当前总资产: 367113.55 *****
# [INFO] 2019-01-01 14:25:21 当前理财资产和非理财资产总额构成如下:
# ***** 理财账户: 24585.0  非理财账户: 342528.55 *****
# [INFO] 2019-01-01 14:25:21
# *****理财账户占比: 0.0669683807639353 *****
#                                                                     current_value
# date       account_type channel category subclass item
# 2019-01-01 理财账户         华泰证券    现金       现金       股票空仓闲置资金                5583.00
#                                 股票       股票       格力电器                   10707.00
#                         工行8987  现金       现金       活期存款                    8295.00
#            非理财账户        交行信用卡   负债       负债       透支金额                    -531.00
#                         京东白条    负债       负债       透支金额                   -1229.00
#                         京东金融    基金       货币型基金    零用钱                     3003.00
#                                 定期       短期定期     定期                     16069.00
#                         建行3507  现金       现金       活期存款                   45431.00
#                         微信理财通   基金       货币型基金    华夏财富宝                  10544.00
#                                 定期       短期定期     定期                    164851.00
#                         微信零钱    现金       现金       零钱通                     3425.00
#                         支付宝_151 基金       指数型基金    广发沪深300ETF002987       12490.44
#                                          纯债型基金    博时富华纯债债券003730         10127.93
#                                                   大摩强收益债券233005          10099.74
#                                          货币型基金    余额宝                    26414.00
#                                                   建信现金增利货币002758         30166.44
#                                 定期       短期定期     建信养老飞月宝                20132.00
#                                 负债       负债       花呗透支额度                 -8465.00

# %% [markdown]
# # 读取指定日期净资产结构

# %%
# 读取给定时间间隔之间的所有净资产结构记录  默认为读取最新日期
fa.get_net_asset_structure()
# Out:
#                               current_value
# date       category subclass
# 2019-01-01 基金       指数型基金          12490.44
#                     纯债型基金          20227.67
#                     货币型基金          70127.44
#            定期       短期定期          201052.00
#            现金       现金             62734.00
#            股票       股票             10707.00
#            负债       负债            -10225.00

# %% [markdown]
# # 读取指定日期的理财账户下资产结构及配置合理度

# %%
# 读取给定时间间隔之间的所有资产结构及配置记录  默认为读取最新日期
fa.get_big_asset_configure()
# Out:
# [INFO] 2019-01-01 14:25:26
# date_config为配置信息日期不为空 date为mv表记录日期 date为空表示当前日期下理财账户并未配置该类资产
#                date date_config category subclass  current_value       pct  \
# 0               NaN  2019-01-01       基金    主动型基金            NaN       NaN
# 1               NaN  2019-01-01       基金    指数型基金            NaN       NaN
# 2               NaN  2019-01-01       基金    纯债型基金            NaN       NaN
# 3        2019-01-01  2019-01-01       基金    货币型基金            0.0  0.000000
# 4               NaN  2019-01-01       定期    中长期定期            NaN       NaN
# 5               NaN  2019-01-01       定期     短期定期            NaN       NaN
# 6        2019-01-01  2019-01-01       现金       现金        13878.0  0.564491
# 7        2019-01-01  2019-01-01       股票       股票        10707.0  0.435509
# row_sum         NaN         NaN      NaN      NaN        24585.0  1.000000
#
#          planning_prop      diff
# 0                 0.00       NaN
# 1                 0.17       NaN
# 2                 0.33       NaN
# 3                 0.07   1720.95
# 4                 0.03       NaN
# 5                 0.23       NaN
# 6                 0.07 -12157.05
# 7                 0.10  -8248.50
# row_sum           1.00       NaN

# %% [markdown]
# # 读取最新记录日的所有权益类资产的收益记录

# %%
fa.get_equity_return_records()
# Out:
#           date              item  order status  hold_days  buy_cost  \
# 6   2019-01-01    博时富华纯债债券003730      1    持仓中         54  10000.00
# 9   2019-01-01     大摩强收益债券233005      2    持仓中         54  10000.00
# 13  2019-01-01  广发沪深300ETF002987      4    持仓中         67  13000.00
# 17  2019-01-01              格力电器      1    持仓中         42  11120.22
# 0   2019-01-01              上海医药      1   落袋为安         60   9726.40
# 1   2019-01-01              伊利股份      1   落袋为安         20  10570.21
# 2   2019-01-01              华域汽车      1   落袋为安         65  13032.00
# 3   2019-01-01              华泰证券      1   落袋为安         40  13615.27
# 4   2019-01-01              华泰证券      2   落袋为安         68   6244.00
# 5   2019-01-01              华海药业      1   落袋为安          4   2265.05
# 7   2019-01-01              复星医药      1   落袋为安         27  11537.23
# 8   2019-01-01     大摩强收益债券233005      1   落袋为安        101  37000.00
# 10  2019-01-01  广发沪深300ETF002987      1   落袋为安        171  24900.00
# 11  2019-01-01  广发沪深300ETF002987      2   落袋为安         49   7500.00
# 12  2019-01-01  广发沪深300ETF002987      3   落袋为安         14   4000.00
# 14  2019-01-01              康缘医药      1   落袋为安         60   1526.00
# 15  2019-01-01              恒瑞医药      1   落袋为安         54  19400.13
# 16  2019-01-01              恒瑞医药      2   落袋为安          7   5545.11
# 18  2019-01-01        银华估值005250      1   落袋为安        213  28470.00
#
#     current_value   return return_rate return_rate_annually  total_return  \
# 6        10127.93   127.93       1.28%                8.65%       1999.28
# 9        10099.74    99.74       1.00%                6.74%       1999.28
# 13       12490.44  -509.56      -3.92%              -21.35%       1999.28
# 17       10707.00  -413.22      -3.72%              -32.29%       1999.28
# 0             NaN   445.60       4.58%               27.87%       1999.28
# 1             NaN   805.17       7.62%              139.02%       1999.28
# 2             NaN   464.21       3.56%               20.00%       1999.28
# 3             NaN   496.32       3.65%               33.26%       1999.28
# 4             NaN  -364.00      -5.83%              -31.29%       1999.28
# 5             NaN   303.32      13.39%             1221.96%       1999.28
# 7             NaN  1374.58      11.91%              161.06%       1999.28
# 8             NaN    75.00       0.20%                0.73%       1999.28
# 10            NaN -1037.27      -4.17%               -8.89%       1999.28
# 11            NaN   275.60       3.67%               27.37%       1999.28
# 12            NaN    96.59       2.41%               62.96%       1999.28
# 14            NaN  -120.00      -7.86%              -47.84%       1999.28
# 15            NaN  -134.68      -0.69%               -4.69%       1999.28
# 16            NaN   219.99       3.97%              206.87%       1999.28
# 18            NaN  -206.04      -0.72%               -1.24%       1999.28
#
#    overall_return_rate
# 6                0.83%
# 9                0.83%
# 13               0.83%
# 17               0.83%
# 0                0.83%
# 1                0.83%
# 2                0.83%
# 3                0.83%
# 4                0.83%
# 5                0.83%
# 7                0.83%
# 8                0.83%
# 10               0.83%
# 11               0.83%
# 12               0.83%
# 14               0.83%
# 15               0.83%
# 16               0.83%
# 18               0.83%

# %% [markdown]
# # 读取权益类资产绝对收益变化情况

# %%
fa.get_equity_return_change()
# Out:
# date
# 2019-01-01    1999.28
# Name: return, dtype: float64

# %% [markdown]
# # 获取净资产-来自父母收入的差异变化

# %%
fa.get_diff_from_parents_change(house_net_value=210-126)
# Out:
# [INFO] 2019-01-01 14:25:32
# diff_real=diff+房产的净值:
# diff_real=0表示当前资产全部来自父母
# diff_real>0 表示属于自己资产的部分
# 最新估计的diff_real: -9659.449999999953
#        date  parents_cumsum  current_net_asset        diff
# 0   2016-08        269387.0               0.00  -269387.00
# 1   2017-02        336908.0               0.00  -336908.00
# 2   2017-03        352824.0               0.00  -352824.00
# 3   2017-04        358811.0               0.00  -358811.00
# 4   2017-05        374800.0               0.00  -374800.00
# 5   2017-06        394257.0               0.00  -394257.00
# 6   2017-07        409321.0               0.00  -409321.00
# 7   2017-08        448750.0               0.00  -448750.00
# 8   2017-09        476405.0               0.00  -476405.00
# 9   2017-10        512212.0               0.00  -512212.00
# 10  2017-11        540043.0               0.00  -540043.00
# 11  2017-12        573873.0          540624.00   -33249.00
# 12  2018-01        598447.0          551367.00   -47080.00
# 13  2018-02        643315.0          587982.00   -55333.00
# 14  2018-03        680025.0          629240.94   -50784.06
# 15  2018-04        775313.0          726121.26   -49191.74
# 16  2018-05        962413.0          910124.50   -52288.50
# 17  2018-06       1180153.0               0.00 -1180153.00
# 18  2018-07       1185053.0               0.00 -1185053.00
# 19  2018-08       1185053.0          392518.51  -792534.49
# 20  2018-09       1194813.0               0.00 -1194813.00
# 21  2018-10       1216773.0               0.00 -1216773.00
# 22  2018-11       1216773.0          382061.00  -834712.00
# 23  2018-12       1216773.0          367113.55  -849659.45
